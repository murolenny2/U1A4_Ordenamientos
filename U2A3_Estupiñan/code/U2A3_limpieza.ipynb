# %%
import pandas as pd

df = pd.read_csv("../data/raw/encuesta.csv")

print("Filas y columnas:")
print(df.shape)

print("\nInformación:")
print(df.info())

print("\nValores faltantes:")
print(df.isnull().sum())
# Out:
# Filas y columnas:
# (82, 27)
#
# Información:
# <class 'pandas.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 27 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   ID                                                           82 non-null     int64
#  1   Tu Semestre Actual                                           82 non-null     str
#  2   Eres originario de Guadalupe Victoria?                       82 non-null     str
#  3   El Tecnológico de los Llanos fue tu:                         82 non-null     str
#  4   ¿Por qué elegiste esta institución? (elige máximo 3)         82 non-null     str
#  5   Si no fue tu primera opción, ¿cuál fue el motivo principal?  82 non-null     str
#  6   Ingeniería Mecatrónica fue tu:                               82 non-null     str
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/raw/encuesta.csv")

print("Filas y columnas:", df.shape)

df.head()
# Out:
# Filas y columnas: (82, 27)
#    ID Tu Semestre Actual Eres originario de Guadalupe Victoria?  \
# 0   1                 8°                                     Si
# 1   2                 8°                                     No
# 2   3                 8°                                     No
# 3   4                 8°                                     No
# 4   5                 8°                                     Si
#
#   El Tecnológico de los Llanos fue tu:  \
# 0                           2da opcion
# 1                           1er opcion
# 2                           1er opcion
# 3                           2da opcion
# 4                    3er opción o más
#
#   ¿Por qué elegiste esta institución? (elige máximo 3)  \
# 0  Cercanía a mi domicilio;Recomendación de famil...
# 1  Cercanía a mi domicilio;Costo accesible;Recome...
# 2  Cercanía a mi domicilio;Recomendación de famil...
# 3                           Cercanía a mi domicilio;
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 27 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   ID                                                           82 non-null     int64
#  1   Tu Semestre Actual                                           82 non-null     str
#  2   Eres originario de Guadalupe Victoria?                       82 non-null     str
#  3   El Tecnológico de los Llanos fue tu:                         82 non-null     str
#  4   ¿Por qué elegiste esta institución? (elige máximo 3)         82 non-null     str
#  5   Si no fue tu primera opción, ¿cuál fue el motivo principal?  82 non-null     str
#  6   Ingeniería Mecatrónica fue tu:                               82 non-null     str
#  7   Motivo principal para elegir Mecatrónica                     82 non-null     str
# ...

# %%
faltantes = df.isnull().sum()

print(faltantes)
# Out:
# ID                                                              0
# Tu Semestre Actual                                              0
# Eres originario de Guadalupe Victoria?                          0
# El Tecnológico de los Llanos fue tu:                            0
# ¿Por qué elegiste esta institución? (elige máximo 3)            0
# Si no fue tu primera opción, ¿cuál fue el motivo principal?     0
# Ingeniería Mecatrónica fue tu:                                  0
# Motivo principal para elegir Mecatrónica                        0
# Antes de ingresar, tu conocimiento sobre la carrera era:        0
# Percepcion de Calidad académica general de la carrera           0
# Como consideras el nivel de los docentes                        0
# Preparación técnica que estás recibiendo                        0
# Actualización tecnológica de contenidos                         0
# Uso de laboratorios y prácticas                                 0
# ...

# %%
duplicados = df.duplicated().sum()

print("Duplicados encontrados:", duplicados)
# Out:
# Duplicados encontrados: 0

# %%
calidad = pd.DataFrame({
    "Valores Faltantes": df.isnull().sum(),
    "Tipo de Dato": df.dtypes
})

calidad
# Out:
#                                                     Valores Faltantes  \
# ID                                                                  0
# Tu Semestre Actual                                                  0
# Eres originario de Guadalupe Victoria?                              0
# El Tecnológico de los Llanos fue tu:                                0
# ¿Por qué elegiste esta institución? (elige máxi...                  0
# Si no fue tu primera opción, ¿cuál fue el motiv...                  0
# Ingeniería Mecatrónica fue tu:                                      0
# Motivo principal para elegir Mecatrónica                            0
# Antes de ingresar, tu conocimiento sobre la car...                  0
# Percepcion de Calidad académica general de la c...                  0
# Como consideras el nivel de los docentes                            0
# Preparación técnica que estás recibiendo                            0
# ...

# %%
df_limpio = df.copy()

print("Copia creada correctamente")
# Out:
# Copia creada correctamente

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Que tan importante es para ti los Deportes institucionales     1
# Si no participas, el motivo principal es:                     38
# ¿Has pensado en dejar la carrera?                             18
# dtype: int64

# %%
for col in df.columns:
    if df[col].dtype == "object":
        print("\n====================")
        print(col)
        print(df[col].dropna().unique()[:20])

# %%
registro_cambios = []

# %%
print(df.columns)
# Out:
# Index(['ID', 'Tu Semestre Actual', 'Eres originario de Guadalupe Victoria?',
#        'El Tecnológico de los Llanos fue tu:',
#        '¿Por qué elegiste esta institución? (elige máximo 3)',
#        'Si no fue tu primera opción, ¿cuál fue el motivo principal?',
#        'Ingeniería Mecatrónica fue tu:',
#        'Motivo principal para elegir Mecatrónica ',
#        'Antes de ingresar, tu conocimiento sobre la carrera era:',
#        'Percepcion de Calidad académica general de la carrera',
#        'Como consideras el nivel de los docentes',
#        'Preparación técnica que estás recibiendo',
#        'Actualización tecnológica de contenidos',
#        'Uso de laboratorios y prácticas', 'Vinculación con industria',
#        '¿Qué deberían mejorar los docentes? (máximo 2)',
#        'Como sientes el Nivel de exigencia académica actual:',
#        'Participación en concursos de robótica/tecnología',
#        'Participación en proyectos de investigación',
# ...

# %%
print(df.select_dtypes(include="object").columns)
# Out:
# Index(['Tu Semestre Actual', 'Eres originario de Guadalupe Victoria?',
#        'El Tecnológico de los Llanos fue tu:',
#        '¿Por qué elegiste esta institución? (elige máximo 3)',
#        'Si no fue tu primera opción, ¿cuál fue el motivo principal?',
#        'Ingeniería Mecatrónica fue tu:',
#        'Motivo principal para elegir Mecatrónica ',
#        'Antes de ingresar, tu conocimiento sobre la carrera era:',
#        'Percepcion de Calidad académica general de la carrera',
#        'Como consideras el nivel de los docentes',
#        'Preparación técnica que estás recibiendo',
#        'Actualización tecnológica de contenidos',
#        'Uso de laboratorios y prácticas', 'Vinculación con industria',
#        '¿Qué deberían mejorar los docentes? (máximo 2)',
#        'Como sientes el Nivel de exigencia académica actual:',
#        'Participación en concursos de robótica/tecnología',
#        'Participación en proyectos de investigación',
# ...

# %%
print(df.select_dtypes(include="object").columns)
# Out:
# Index(['Tu Semestre Actual', 'Eres originario de Guadalupe Victoria?',
#        'El Tecnológico de los Llanos fue tu:',
#        '¿Por qué elegiste esta institución? (elige máximo 3)',
#        'Si no fue tu primera opción, ¿cuál fue el motivo principal?',
#        'Ingeniería Mecatrónica fue tu:',
#        'Motivo principal para elegir Mecatrónica ',
#        'Antes de ingresar, tu conocimiento sobre la carrera era:',
#        'Percepcion de Calidad académica general de la carrera',
#        'Como consideras el nivel de los docentes',
#        'Preparación técnica que estás recibiendo',
#        'Actualización tecnológica de contenidos',
#        'Uso de laboratorios y prácticas', 'Vinculación con industria',
#        '¿Qué deberían mejorar los docentes? (máximo 2)',
#        'Como sientes el Nivel de exigencia académica actual:',
#        'Participación en concursos de robótica/tecnología',
#        'Participación en proyectos de investigación',
# ...

# %%
col_texto = df.select_dtypes(include="object").columns[0]

print("Columna:")
print(col_texto)

print("\nValores:")
print(df[col_texto].value_counts())
# Out:
# Columna:
# Tu Semestre Actual
#
# Valores:
# Tu Semestre Actual
# 2°    24
# 4°    23
# 8°    18
# 6°    17
# Name: count, dtype: int64
# C:\Users\estup\AppData\Local\Temp\ipykernel_37812\658622066.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   col_texto = df.select_dtypes(include="object").columns[0]

# %%
df_limpio.to_csv(
    "../data/processed/encuesta_limpia.csv",
    index=False
)

print("Dataset limpio guardado correctamente")
# Out:
# Dataset limpio guardado correctamente

# %%
cambios = pd.DataFrame({
    "Problema": [
        "Valores faltantes",
        "Duplicados"
    ],
    "Accion": [
        "Reemplazo por etiquetas descriptivas",
        "Verificación"
    ],
    "Resultado": [
        "57 valores corregidos",
        "0 duplicados encontrados"
    ]
})

cambios
# Out:
#             Problema                                Accion  \
# 0  Valores faltantes  Reemplazo por etiquetas descriptivas
# 1         Duplicados                          Verificación
#
#                   Resultado
# 0     57 valores corregidos
# 1  0 duplicados encontrados
